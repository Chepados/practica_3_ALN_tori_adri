# %% [markdown]
# # ACCESS to Hooktheory API

# %%
import requests
import pandas as pd
import time

# %% [markdown]
# Necesitamos unas credenciales para acceder a la API

# %%
def get_auth_key(username, password):
    auth_url = "https://api.hooktheory.com/v1/users/auth"
    auth_data = {
        "username": username,
        "password": password
    }
    
    # Solicitar token de autenticación
    auth_response = requests.post(auth_url, json=auth_data)
    
    if auth_response.status_code == 200:
        return auth_response.json()["activkey"]
    else:
        raise Exception(f"Error en la autenticación: {auth_response.status_code} - {auth_response.text}")
    

my_key = get_auth_key("ivantoribio", "MusicIsForEveryone12")

my_key
# Out:
# 'e02a2d8962a0c70fc763994e9fb41f02'

# %% [markdown]
# Creamos una función para conseguir todas las canciones en la base de datos que siguen una determinada progresión

# %%
def get_songs_by_progression(auth_key, progression):
    songs_url = f"https://api.hooktheory.com/v1/trends/songs?cp={progression}"
    
    headers = {
        "Authorization": f"Bearer {auth_key}",
        "Accept": "application/json",
        "Content-Type": "application/json"
    }
    
    songs_data = []
    page = 1
    
    while page <= 5:
        # Añadimos paginación en caso de que haya muchas canciones
        response = requests.get(songs_url + f"&page={page}", headers=headers)
        
        if response.status_code != 200:
            raise Exception(f"Error al obtener canciones: {response.status_code} - {response.text}")
        
        songs = response.json()
        
        if not songs:
            break  # Salimos si no hay más canciones en la siguiente página

        # Agregamos cada canción a nuestra lista
        for song in songs:
            songs_data.append({
                "artist": song["artist"],
                "song": song["song"],
                "section": song["section"],
                "url": song["url"],
                "progression": progression
            })
        
        time.sleep(1)
        page += 1  # Avanzamos a la siguiente página

    return songs_data

get_songs_by_progression(my_key, "4,1")
# Out:
# [{'artist': 'Adele',
#   'song': 'Someone Like You',
#   'section': 'Chorus',
#   'url': 'http://www.hooktheory.com/theorytab/view/adele/someone-like-you#chorus',
#   'progression': '4,1'},
#  {'artist': 'Adele',
#   'song': 'Someone Like You',
#   'section': 'Verse',
#   'url': 'http://www.hooktheory.com/theorytab/view/adele/someone-like-you#verse',
#   'progression': '4,1'},
#  {'artist': 'Aerosmith',
#   'song': "Cryin'",
#   'section': 'Pre-Chorus',
#   'url': 'http://www.hooktheory.com/theorytab/view/aerosmith/cryin#pre-chorus',
#   'progression': '4,1'},
#  {'artist': 'Aerosmith',
#   'song': "Cryin'",
#   'section': 'Verse',
#   'url': 'http://www.hooktheory.com/theorytab/view/aerosmith/cryin#verse',
#   'progression': '4,1'},
#  {'artist': 'Alt-J',
#   'song': 'Something Good',
#   'section': 'Verse',
#   'url': 'http://www.hooktheory.com/theorytab/view/alt-j/something-good#verse',
#   'progression': '4,1'},
#  {'artist': 'Augustana',
#   'song': 'Boston',
#   'section': 'Verse',
#   'url': 'http://www.hooktheory.com/theorytab/view/augustana/boston#verse',
#   'progression': '4,1'},
#  {'artist': 'Avril Lavigne',
#   'song': 'Girlfriend',
#   'section': 'Chorus',
#   'url': 'http://www.hooktheory.com/theorytab/view/avril-lavigne/girlfriend#chorus',
#   'progression': '4,1'},
#  {'artist': 'B o B ft Hayley Williams',
#   'song': 'Airplanes',
#   'section': 'Chorus',
#   'url': 'http://www.hooktheory.com/theorytab/view/b-o-b-ft-hayley-williams/airplanes#chorus',
#   'progression': '4,1'},
#  {'artist': 'Beyonce',
#   'song': 'Halo',
#   'section': 'Verse',
#   'url': 'http://www.hooktheory.com/theorytab/view/beyonce/halo#verse',
#   'progression': '4,1'},
#  {'artist': 'Billy Joel',
#   'song': 'Piano Man',
#   'section': 'Chorus',
#   'url': 'http://www.hooktheory.com/theorytab/view/billy-joel/piano-man#chorus',
#   'progression': '4,1'},
#  {'artist': 'Billy Joel',
#   'song': "She's Always a Woman",
#   'section': 'Verse',
#   'url': 'http://www.hooktheory.com/theorytab/view/billy-joel/shes-always-a-woman#verse',
#   'progression': '4,1'},
#  {'artist': 'Bing Crosby',
#   'song': 'White Christmas',
#   'section': 'Verse',
#   'url': 'http://www.hooktheory.com/theorytab/view/bing-crosby/white-christmas#verse',
#   'progression': '4,1'},
#  {'artist': 'Black Eyed Peas',
#   'song': "Just Can't Get Enough",
#   'section': 'Chorus',
#   'url': 'http://www.hooktheory.com/theorytab/view/black-eyed-peas/just-cant-get-enough#chorus',
#   'progression': '4,1'},
#  {'artist': 'Blink 182',
#   'song': 'All The Small Things',
#   'section': 'Verse and Pre-Chorus',
#   'url': 'http://www.hooktheory.com/theorytab/view/blink-182/all-the-small-things#verse-and-pre-chorus',
#   'progression': '4,1'},
#  {'artist': 'Blues Traveler',
#   'song': 'Hook',
#   'section': 'Verse',
#   'url': 'http://www.hooktheory.com/theorytab/view/blues-traveler/hook#verse',
#   'progression': '4,1'},
#  {'artist': 'Bon Jovi',
#   'song': "Who says you can't go home",
#   'section': 'Chorus',
#   'url': 'http://www.hooktheory.com/theorytab/view/bon-jovi/who-says-you-cant-go-home#chorus',
#   'progression': '4,1'},
#  {'artist': 'Bruno Mars',
#   'song': 'Grenade',
#   'section': 'Chorus',
#   'url': 'http://www.hooktheory.com/theorytab/view/bruno-mars/grenade#chorus',
#   'progression': '4,1'},
#  {'artist': 'Bruno Mars',
#   'song': 'Just The Way You Are',
#   'section': 'Chorus',
#   'url': 'http://www.hooktheory.com/theorytab/view/bruno-mars/just-the-way-you-are#chorus',
#   'progression': '4,1'},
#  {'artist': 'Bruno Mars',
#   'song': 'Just The Way You Are',
#   'section': 'Verse',
#   'url': 'http://www.hooktheory.com/theorytab/view/bruno-mars/just-the-way-you-are#verse',
#   'progression': '4,1'},
#  {'artist': 'Bruno Mars',
#   'song': 'The Lazy Song',
#   'section': 'Chorus',
#   'url': 'http://www.hooktheory.com/theorytab/view/bruno-mars/the-lazy-song#chorus',
#   'progression': '4,1'},
#  {'artist': 'Bryan Adams',
#   'song': 'Everything I Do',
#   'section': 'Verse',
#   'url': 'http://www.hooktheory.com/theorytab/view/bryan-adams/everything-i-do#verse',
#   'progression': '4,1'},
#  {'artist': 'Buddy Holly',
#   'song': "That'll Be The Day",
#   'section': 'Verse',
#   'url': 'http://www.hooktheory.com/theorytab/view/buddy-holly/thatll-be-the-day#verse',
#   'progression': '4,1'},
#  {'artist': 'Carly Rae Jepsen',
#   'song': 'Call Me Maybe',
#   'section': 'Chorus',
#   'url': 'http://www.hooktheory.com/theorytab/view/carly-rae-jepsen/call-me-maybe#chorus',
#   'progression': '4,1'},
#  {'artist': 'Carrie Underwood',
#   'song': 'So Small',
#   'section': 'Chorus',
#   'url': 'http://www.hooktheory.com/theorytab/view/carrie-underwood/so-small#chorus',
#   'progression': '4,1'},
#  {'artist': 'Carrie Underwood',
#   'song': 'So Small',
#   'section': 'Verse',
#   'url': 'http://www.hooktheory.com/theorytab/view/carrie-underwood/so-small#verse',
#   'progression': '4,1'},
#  {'artist': 'Cascada',
#   'song': 'Every Time We Touch',
#   'section': 'Chorus',
#   'url': 'http://www.hooktheory.com/theorytab/view/cascada/every-time-we-touch#chorus',
#   'progression': '4,1'},
#  {'artist': 'Cascada',
#   'song': 'Every Time We Touch',
#   'section': 'Verse',
#   'url': 'http://www.hooktheory.com/theorytab/view/cascada/every-time-we-touch#verse',
#   'progression': '4,1'},
#  {'artist': 'Cee Lo Green',
#   'song': 'Forget You',
#   'section': 'Verse',
#   'url': 'http://www.hooktheory.com/theorytab/view/cee-lo-green/forget-you#verse',
#   'progression': '4,1'},
#  {'artist': 'Celine Dion',
#   'song': 'My Heart Will Go On',
#   'section': 'Verse',
#   'url': 'http://www.hooktheory.com/theorytab/view/celine-dion/my-heart-will-go-on#verse',
#   'progression': '4,1'},
#  {'artist': 'Cheryl Cole',
#   'song': 'Parachute',
#   'section': 'Chorus',
#   'url': 'http://www.hooktheory.com/theorytab/view/cheryl-cole/parachute#chorus',
#   'progression': '4,1'},
#  {'artist': 'Cheryl Cole',
#   'song': 'Parachute',
#   'section': 'Verse',
#   'url': 'http://www.hooktheory.com/theorytab/view/cheryl-cole/parachute#verse',
#   'progression': '4,1'},
#  {'artist': 'Chuck Berry',
#   'song': 'Maybellene',
#   'section': 'Chorus',
#   'url': 'http://www.hooktheory.com/theorytab/view/chuck-berry/maybellene#chorus',
#   'progression': '4,1'},
#  {'artist': 'Colbie Caillat',
#   'song': 'Realize',
#   'section': 'Chorus',
#   'url': 'http://www.hooktheory.com/theorytab/view/colbie-caillat/realize#chorus',
#   'progression': '4,1'},
#  {'artist': 'Coldplay',
#   'song': 'Hurts Like Heaven',
#   'section': 'Verse',
#   'url': 'http://www.hooktheory.com/theorytab/view/coldplay/hurts-like-heaven#verse',
#   'progression': '4,1'},
#  {'artist': 'Coldplay',
#   'song': 'The Scientist',
#   'section': 'Intro',
#   'url': 'http://www.hooktheory.com/theorytab/view/coldplay/the-scientist#intro',
#   'progression': '4,1'},
#  {'artist': 'Coldplay',
#   'song': 'The Scientist',
#   'section': 'Verse',
#   'url': 'http://www.hooktheory.com/theorytab/view/coldplay/the-scientist#verse',
#   'progression': '4,1'},
#  {'artist': 'Counting Crows',
#   'song': 'A Long December',
#   'section': 'Verse',
#   'url': 'http://www.hooktheory.com/theorytab/view/counting-crows/a-long-december#verse',
#   'progression': '4,1'},
#  {'artist': 'Counting Crows',
#   'song': 'Walkaways',
#   'section': 'Verse',
#   'url': 'http://www.hooktheory.com/theorytab/view/counting-crows/walkaways#verse',
#   'progression': '4,1'},
#  {'artist': 'Creedence Clearwater Revival',
#   'song': 'Bad Moon Rising',
#   'section': 'Chorus',
#   'url': 'http://www.hooktheory.com/theorytab/view/creedence-clearwater-revival/bad-moon-rising#chorus',
#   'progression': '4,1'},
#  {'artist': 'Creedence Clearwater Revival',
#   'song': 'Bad Moon Rising',
#   'section': 'Verse',
#   'url': 'http://www.hooktheory.com/theorytab/view/creedence-clearwater-revival/bad-moon-rising#verse',
#   'progression': '4,1'},
#  {'artist': 'Creedence Clearwater Revival',
#   'song': 'Up Around the Bend',
#   'section': 'Chorus',
#   'url': 'http://www.hooktheory.com/theorytab/view/creedence-clearwater-revival/up-around-the-bend#chorus',
#   'progression': '4,1'},
#  {'artist': 'Daughtry',
#   'song': 'Home',
#   'section': 'Chorus',
#   'url': 'http://www.hooktheory.com/theorytab/view/daughtry/home#chorus',
#   'progression': '4,1'},
#  {'artist': 'Daughtry',
#   'song': 'Home',
#   'section': 'Pre-Chorus',
#   'url': 'http://www.hooktheory.com/theorytab/view/daughtry/home#pre-chorus',
#   'progression': '4,1'},
#  {'artist': 'Daughtry',
#   'song': 'Home',
#   'section': 'Verse',
#   'url': 'http://www.hooktheory.com/theorytab/view/daughtry/home#verse',
#   'progression': '4,1'},
#  {'artist': 'Death Cab for Cutie',
#   'song': 'I Will Follow You Into the Dark',
#   'section': 'Chorus',
#   'url': 'http://www.hooktheory.com/theorytab/view/death-cab-for-cutie/i-will-follow-you-into-the-dark#chorus',
#   'progression': '4,1'},
#  {'artist': 'Death Cab for Cutie',
#   'song': 'I Will Follow You Into the Dark',
#   'section': 'Verse',
#   'url': 'http://www.hooktheory.com/theorytab/view/death-cab-for-cutie/i-will-follow-you-into-the-dark#verse',
#   'progression': '4,1'},
#  {'artist': 'Demi Lovato',
#   'song': 'Give Your Heart A Break',
#   'section': 'Bridge',
#   'url': 'http://www.hooktheory.com/theorytab/view/demi-lovato/give-your-heart-a-break#bridge',
#   'progression': '4,1'},
#  {'artist': 'Demi Lovato',
#   'song': 'Give Your Heart A Break',
#   'section': 'Chorus',
#   'url': 'http://www.hooktheory.com/theorytab/view/demi-lovato/give-your-heart-a-break#chorus',
#   'progression': '4,1'},
#  {'artist': 'Demi Lovato',
#   'song': 'Give Your Heart A Break',
#   'section': 'Pre-Chorus',
#   'url': 'http://www.hooktheory.com/theorytab/view/demi-lovato/give-your-heart-a-break#pre-chorus',
#   'progression': '4,1'},
#  {'artist': 'Demi Lovato',
#   'song': 'Give Your Heart A Break',
#   'section': 'Verse',
#   'url': 'http://www.hooktheory.com/theorytab/view/demi-lovato/give-your-heart-a-break#verse',
#   'progression': '4,1'},
#  {'artist': 'Demi Lovato',
#   'song': 'Here We Go Again',
#   'section': 'Intro and Verse',
#   'url': 'http://www.hooktheory.com/theorytab/view/demi-lovato/here-we-go-again#intro-and-verse',
#   'progression': '4,1'},
#  {'artist': 'Demi Lovato',
#   'song': 'Skyscraper',
#   'section': 'Bridge',
#   'url': 'http://www.hooktheory.com/theorytab/view/demi-lovato/skyscraper#bridge',
#   'progression': '4,1'},
#  {'artist': 'Demi Lovato',
#   'song': 'Skyscraper',
#   'section': 'Intro',
#   'url': 'http://www.hooktheory.com/theorytab/view/demi-lovato/skyscraper#intro',
#   'progression': '4,1'},
#  {'artist': 'Diana Ross',
#   'song': 'If We Hold On Together',
#   'section': 'Pre-Chorus',
#   'url': 'http://www.hooktheory.com/theorytab/view/diana-ross/if-we-hold-on-together#pre-chorus',
#   'progression': '4,1'},
#  {'artist': 'Dire Straits',
#   'song': 'Money For Nothing',
#   'section': 'Chorus',
#   'url': 'http://www.hooktheory.com/theorytab/view/dire-straits/money-for-nothing#chorus',
#   'progression': '4,1'},
#  {'artist': 'Dire Straits',
#   'song': 'Skateaway',
#   'section': 'Verse',
#   'url': 'http://www.hooktheory.com/theorytab/view/dire-straits/skateaway#verse',
#   'progression': '4,1'},
#  {'artist': 'Disney',
#   'song': 'Can You Feel The Love Tonight',
#   'section': 'Chorus',
#   'url': 'http://www.hooktheory.com/theorytab/view/disney/can-you-feel-the-love-tonight#chorus',
#   'progression': '4,1'},
#  {'artist': 'Don McLean',
#   'song': 'American Pie',
#   'section': 'Chorus',
#   'url': 'http://www.hooktheory.com/theorytab/view/don-mclean/american-pie#chorus',
#   'progression': '4,1'},
#  {'artist': 'Eagles',
#   'song': 'Desperado',
#   'section': 'Verse',
#   'url': 'http://www.hooktheory.com/theorytab/view/eagles/desperado#verse',
#   'progression': '4,1'},
#  {'artist': 'Ed Sheeran',
#   'song': 'A Team',
#   'section': 'Verse',
#   'url': 'http://www.hooktheory.com/theorytab/view/ed-sheeran/a-team#verse',
#   'progression': '4,1'},
#  {'artist': 'Elliott Smith',
#   'song': 'Say Yes',
#   'section': 'Outro',
#   'url': 'http://www.hooktheory.com/theorytab/view/elliott-smith/say-yes#outro',
#   'progression': '4,1'},
#  {'artist': 'Elton John',
#   'song': 'Can You Feel the Love Tonight',
#   'section': 'Chorus',
#   'url': 'http://www.hooktheory.com/theorytab/view/elton-john/can-you-feel-the-love-tonight#chorus',
#   'progression': '4,1'},
#  {'artist': 'Elton John',
#   'song': 'Levon',
#   'section': 'Instrumental',
#   'url': 'http://www.hooktheory.com/theorytab/view/elton-john/levon#instrumental',
#   'progression': '4,1'},
#  {'artist': 'Elton John',
#   'song': 'Levon',
#   'section': 'Intro',
#   'url': 'http://www.hooktheory.com/theorytab/view/elton-john/levon#intro',
#   'progression': '4,1'},
#  {'artist': 'Elton John',
#   'song': 'Levon',
#   'section': 'Verse',
#   'url': 'http://www.hooktheory.com/theorytab/view/elton-john/levon#verse',
#   'progression': '4,1'},
#  {'artist': 'Eminem',
#   'song': 'Love The Way You Lie ft Rihanna',
#   'section': 'Chorus',
#   'url': 'http://www.hooktheory.com/theorytab/view/eminem/love-the-way-you-lie-ft-rihanna#chorus',
#   'progression': '4,1'},
#  {'artist': 'Eminem',
#   'song': 'Love The Way You Lie ft Rihanna',
#   'section': 'Verse',
#   'url': 'http://www.hooktheory.com/theorytab/view/eminem/love-the-way-you-lie-ft-rihanna#verse',
#   'progression': '4,1'},
#  {'artist': 'Epic Sax Guy',
#   'song': 'Epic Sax Guy',
#   'section': 'Verse',
#   'url': 'http://www.hooktheory.com/theorytab/view/epic-sax-guy/epic-sax-guy#verse',
#   'progression': '4,1'},
#  {'artist': 'Erasure',
#   'song': 'Always',
#   'section': 'Pre-Chorus',
#   'url': 'http://www.hooktheory.com/theorytab/view/erasure/always#pre-chorus',
#   'progression': '4,1'},
#  {'artist': 'Five For Fighting',
#   'song': '100 Years',
#   'section': 'Chorus Lead-Out',
#   'url': 'http://www.hooktheory.com/theorytab/view/five-for-fighting/100-years#chorus-lead-out',
#   'progression': '4,1'},
#  {'artist': 'Flo Rida',
#   'song': 'Whistle',
#   'section': 'Instrumental',
#   'url': 'http://www.hooktheory.com/theorytab/view/flo-rida/whistle#instrumental',
#   'progression': '4,1'},
#  {'artist': 'Foster the People',
#   'song': 'Pumped Up Kicks',
#   'section': 'Chorus',
#   'url': 'http://www.hooktheory.com/theorytab/view/foster-the-people/pumped-up-kicks#chorus',
#   'progression': '4,1'},
#  {'artist': 'Foster the People',
#   'song': 'Pumped Up Kicks',
#   'section': 'Verse',
#   'url': 'http://www.hooktheory.com/theorytab/view/foster-the-people/pumped-up-kicks#verse',
#   'progression': '4,1'},
#  {'artist': 'Frog Fractions Soundtrack',
#   'song': 'Rimushotto Bungie Jump',
#   'section': 'Chorus',
#   'url': 'http://www.hooktheory.com/theorytab/view/frog-fractions-soundtrack/rimushotto-bungie-jump#chorus',
#   'progression': '4,1'},
#  {'artist': 'Fun',
#   'song': 'Some Nights',
#   'section': 'Chorus',
#   'url': 'http://www.hooktheory.com/theorytab/view/fun/some-nights#chorus',
#   'progression': '4,1'},
#  {'artist': 'Goo Goo Dolls',
#   'song': 'Iris',
#   'section': 'Verse',
#   'url': 'http://www.hooktheory.com/theorytab/view/goo-goo-dolls/iris#verse',
#   'progression': '4,1'},
#  {'artist': 'Green Day',
#   'song': 'Basket Case',
#   'section': 'Verse',
#   'url': 'http://www.hooktheory.com/theorytab/view/green-day/basket-case#verse',
#   'progression': '4,1'},
#  {'artist': "Guns N' Roses",
#   'song': 'November Rain',
#   'section': 'Bridge',
#   'url': 'http://www.hooktheory.com/theorytab/view/guns-n-roses/november-rain#bridge',
#   'progression': '4,1'},
#  {'artist': "Guns N' Roses",
#   'song': 'November Rain',
#   'section': 'Instrumental',
#   'url': 'http://www.hooktheory.com/theorytab/view/guns-n-roses/november-rain#instrumental',
#   'progression': '4,1'},
#  {'artist': "Guns N' Roses",
#   'song': "Sweet Child O' Mine",
#   'section': 'Intro',
#   'url': 'http://www.hooktheory.com/theorytab/view/guns-n-roses/sweet-child-o-mine#intro',
#   'progression': '4,1'},
#  {'artist': "Guns N' Roses",
#   'song': "Sweet Child O' Mine",
#   'section': 'Solo',
#   'url': 'http://www.hooktheory.com/theorytab/view/guns-n-roses/sweet-child-o-mine#solo',
#   'progression': '4,1'},
#  {'artist': 'Gym Class Heroes',
#   'song': 'Ass Back Home',
#   'section': 'Chorus',
#   'url': 'http://www.hooktheory.com/theorytab/view/gym-class-heroes/ass-back-home#chorus',
#   'progression': '4,1'},
#  {'artist': 'Hyuna',
#   'song': 'Bubble Pop',
#   'section': 'Chorus',
#   'url': 'http://www.hooktheory.com/theorytab/view/hyuna/bubble-pop#chorus',
#   'progression': '4,1'},
#  {'artist': 'Jack Johnson',
#   'song': 'Flake',
#   'section': 'Verse',
#   'url': 'http://www.hooktheory.com/theorytab/view/jack-johnson/flake#verse',
#   'progression': '4,1'},
#  {'artist': 'James Rich and Boots Randolph',
#   'song': 'Yakety Sax',
#   'section': 'Verse',
#   'url': 'http://www.hooktheory.com/theorytab/view/james-rich-and-boots-randolph/yakety-sax#verse',
#   'progression': '4,1'},
#  {'artist': 'Jason Mraz',
#   'song': "I'm Yours",
#   'section': 'Verse',
#   'url': 'http://www.hooktheory.com/theorytab/view/jason-mraz/im-yours#verse',
#   'progression': '4,1'},
#  {'artist': 'Jessie J',
#   'song': 'Price Tag',
#   'section': 'Chorus',
#   'url': 'http://www.hooktheory.com/theorytab/view/jessie-j/price-tag#chorus',
#   'progression': '4,1'},
#  {'artist': 'Jet',
#   'song': 'Are You Gonna Be My Girl',
#   'section': 'Pre-Chorus and Chorus',
#   'url': 'http://www.hooktheory.com/theorytab/view/jet/are-you-gonna-be-my-girl#pre-chorus-and-chorus',
#   'progression': '4,1'},
#  {'artist': 'John Denver',
#   'song': "Annie's Song",
#   'section': 'Verse',
#   'url': 'http://www.hooktheory.com/theorytab/view/john-denver/annies-song#verse',
#   'progression': '4,1'},
#  {'artist': 'John Lennon',
#   'song': 'Imagine',
#   'section': 'Verse',
#   'url': 'http://www.hooktheory.com/theorytab/view/john-lennon/imagine#verse',
#   'progression': '4,1'},
#  {'artist': 'John Mayer',
#   'song': 'Dreaming With A Broken Heart',
#   'section': 'Verse',
#   'url': 'http://www.hooktheory.com/theorytab/view/john-mayer/dreaming-with-a-broken-heart#verse',
#   'progression': '4,1'},
#  {'artist': 'Johnny Cash',
#   'song': 'I Walk The Line',
#   'section': 'Verse',
#   'url': 'http://www.hooktheory.com/theorytab/view/johnny-cash/i-walk-the-line#verse',
#   'progression': '4,1'},
#  {'artist': 'Jonathan Coulton and Ellen McLain',
#   'song': 'Want You Gone',
#   'section': 'Chorus',
#   'url': 'http://www.hooktheory.com/theorytab/view/jonathan-coulton-and-ellen-mclain/want-you-gone#chorus',
#   'progression': '4,1'},
#  {'artist': 'Journey',
#   'song': "Don't Stop Believing",
#   'section': 'Verse',
#   'url': 'http://www.hooktheory.com/theorytab/view/journey/dont-stop-believing#verse',
#   'progression': '4,1'},
#  {'artist': 'Julia Howe',
#   'song': 'Battle Hymn of the Republic',
#   'section': 'Chorus',
#   'url': 'http://www.hooktheory.com/theorytab/view/julia-howe/battle-hymn-of-the-republic#chorus',
#   'progression': '4,1'},
#  {'artist': 'Julia Howe',
#   'song': 'Battle Hymn of the Republic',
#   'section': 'Verse',
#   'url': 'http://www.hooktheory.com/theorytab/view/julia-howe/battle-hymn-of-the-republic#verse',
#   'progression': '4,1'},
#  {'artist': 'Katy Perry',
#   'song': 'The One That Got Away',
#   'section': 'Chorus',
#   'url': 'http://www.hooktheory.com/theorytab/view/katy-perry/the-one-that-got-away#chorus',
#   'progression': '4,1'},
#  {'artist': 'Katy Perry',
#   'song': 'Wide Awake',
#   'section': 'Chorus',
#   'url': 'http://www.hooktheory.com/theorytab/view/katy-perry/wide-awake#chorus',
#   'progression': '4,1'},
#  {'artist': 'Katy Perry',
#   'song': 'Wide Awake',
#   'section': 'Verse and Pre-Chorus',
#   'url': 'http://www.hooktheory.com/theorytab/view/katy-perry/wide-awake#verse-and-pre-chorus',
#   'progression': '4,1'},
#  {'artist': 'Kelly Clarkson',
#   'song': 'Already Gone',
#   'section': 'Chorus',
#   'url': 'http://www.hooktheory.com/theorytab/view/kelly-clarkson/already-gone#chorus',
#   'progression': '4,1'}]

# %% [markdown]
# Existe un límite de peticiones que podemos hacer a la API. Ese límite es de 10 requests por cada 10 segundos.

# %%
# Hacer una solicitud para obtener datos de la API (por ejemplo, tendencias de nodos)
headers = {
        "Authorization": f"Bearer {my_key}",
        "Accept": "application/json",
        "Content-Type": "application/json"
    }
url = "https://api.hooktheory.com/v1/trends/nodes"
response = requests.get(url, headers=headers)

# Verificar el estado de la respuesta
if response.status_code == 200:
    # Obtener los encabezados de límite de tasa
    rate_limit_limit = response.headers.get("X-Rate-Limit-Limit")
    rate_limit_remaining = response.headers.get("X-Rate-Limit-Remaining")
    rate_limit_reset = response.headers.get("X-Rate-Limit-Reset")

    # Mostrar los valores obtenidos
    print("X-Rate-Limit-Limit:", rate_limit_limit)
    print("X-Rate-Limit-Remaining:", rate_limit_remaining)
    print("X-Rate-Limit-Reset (en segundos):", rate_limit_reset)
else:
    print("Error en la solicitud:", response.status_code, response.text)
# Out:
# X-Rate-Limit-Limit: 10
# X-Rate-Limit-Remaining: 8
# X-Rate-Limit-Reset (en segundos): 2

# %%
def get_progressions(auth_key):
    chords_url = "https://api.hooktheory.com/v1/trends/nodes"
    headers = {
        "Authorization": f"Bearer {auth_key}",
        "Accept": "application/json",
        "Content-Type": "application/json"
    }
    
    chords_response = requests.get(chords_url, headers=headers)
    if chords_response.status_code == 200:
        progressions = [node["child_path"] for node in chords_response.json()]
    else:
        raise Exception(f"Error al obtener acordes: {chords_response.status_code} - {chords_response.text}")

    
    # Limitamos a las primeras progresiones para no exceder el rate limit
    songs_data = []
    for progression in progressions[:5]:  # Cambia el límite si necesitas más progresiones
        print(f"Obteniendo canciones para la progresión: {progression}")
        songs_data.extend(get_songs_by_progression(auth_key, progression))
    
    return songs_data


# Convertimos a DataFrame de pandas
songs_df = pd.DataFrame(get_progressions(my_key))
print(songs_df.head())
# Out:
# Obteniendo canciones para la progresión: 1
# Obteniendo canciones para la progresión: 4
# Obteniendo canciones para la progresión: 6
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[44], line 26
#      22     return songs_data
#      25 # Convertimos a DataFrame de pandas
# ---> 26 songs_df = pd.DataFrame(get_progressions(my_key))
#      27 print(songs_df.head())
#
# Cell In[44], line 20, in get_progressions(auth_key)
#      18 for progression in progressions[:5]:  # Cambia el límite si necesitas más progresiones
#      19     print(f"Obteniendo canciones para la progresión: {progression}")
# ---> 20     songs_data.extend(get_songs_by_progression(auth_key, progression))
#      22 return songs_data
#
# Cell In[41], line 18, in get_songs_by_progression(auth_key, progression)
#      15 response = requests.get(songs_url + f"&page={page}", headers=headers)
#      17 if response.status_code != 200:
# ---> 18     raise Exception(f"Error al obtener canciones: {response.status_code} - {response.text}")
#      20 songs = response.json()
#      22 if not songs:
#
# Exception: Error al obtener canciones: 500 - {"name":"Internal Server Error","message":"An internal server error occurred.","code":0,"status":500}

# %% [markdown]
# La idea es conseguir todas las combinaciones de 4 acordes posibles y capturar las canciones que tienen esas progresiones para almacenar los datos y poder tratarlos en un dataset de pandas.

# %%
import itertools

# Definir los acordes posibles (por ejemplo, del I al VII)
possible_chords = ["1", "2", "3", "4", "5", "6", "7"]

#Definimos cuando una combinacion es válida. Por ejemplo, (1,1,2,4) no lo es pero (1,2,3,1) sí lo es.
def is_valid(combination):
    for i in range(len(combination) - 1):
        if combination[i] == combination[i + 1]:
            return False
    return True


# Generar todas las combinaciones de cuatro acordes posibles
combinations = [combination for combination in itertools.product(possible_chords, repeat=4) if is_valid(combination)]

# Crear DataFrame para almacenar los datos
df_canciones = pd.DataFrame(columns=["cp", "artist", "song", "section", "url"])

# Encabezado para la autenticación (reemplaza "tu_token" por tu activkey)
headers = {
    "Authorization": f"Bearer {my_key}",
    "Accept": "application/json",
    "Content-Type": "application/json"
}

# Función para obtener las canciones para una combinación de acordes
def obtener_canciones(cp):
    url = f"https://api.hooktheory.com/v1/trends/songs?cp={','.join(cp)}"
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        return response.json()
    elif response.status_code == 429:  # Código 429: demasiado tráfico
        wait_time = int(response.headers.get("X-Rate-Limit-Reset", 10))
        print(f"Esperando {wait_time} segundos debido al límite de tasa")
        time.sleep(wait_time)
        return obtener_canciones(cp)  # Reintentar después de esperar
    else:
        print(f"Error {response.status_code}: {response.json()}")
        return []
    
            
# Iterar sobre cada combinación y hacer la solicitud
for cp in combinations:
    canciones = obtener_canciones(cp)
    if canciones:  # Si hay canciones en la respuesta
        for cancion in canciones:
            df_canciones = df_canciones._append({
                "cp": ','.join(cp),
                "artist": cancion["artist"],
                "song": cancion["song"],
                "section": cancion["section"],
                "url": cancion["url"]
            }, ignore_index=True)
    time.sleep(1)  # Pausa de 1 segundo para evitar sobrecarga de solicitudes
# Out:
# Error 500: {'name': 'Internal Server Error', 'message': 'An internal server error occurred.', 'code': 0, 'status': 500}
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File ~/PycharmProjects/MUSIC AI/.venv/lib/python3.12/site-packages/requests/models.py:974, in Response.json(self, **kwargs)
#     973 try:
# --> 974     return complexjson.loads(self.text, **kwargs)
#     975 except JSONDecodeError as e:
#     976     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     977     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/json/__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/json/decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     333 """Return the Python representation of ``s`` (a ``str`` instance
#     334 containing a JSON document).
#     335
#     336 """
# --> 337 obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338 end = _w(s, end).end()
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/json/decoder.py:355, in JSONDecoder.raw_decode(self, s, idx)
#     354 except StopIteration as err:
# --> 355     raise JSONDecodeError("Expecting value", s, err.value) from None
#     356 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# During handling of the above exception, another exception occurred:
#
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[48], line 45
#      43 # Iterar sobre cada combinación y hacer la solicitud
#      44 for cp in combinations:
# ---> 45     canciones = obtener_canciones(cp)
#      46     if canciones:  # Si hay canciones en la respuesta
#      47         for cancion in canciones:
#
# Cell In[48], line 32, in obtener_canciones(cp)
#      30 response = requests.get(url, headers=headers)
#      31 if response.status_code == 200:
# ---> 32     return response.json()
#      33 elif response.status_code == 429:  # Código 429: demasiado tráfico
#      34     wait_time = int(response.headers.get("X-Rate-Limit-Reset", 10))
#
# File ~/PycharmProjects/MUSIC AI/.venv/lib/python3.12/site-packages/requests/models.py:978, in Response.json(self, **kwargs)
#     974     return complexjson.loads(self.text, **kwargs)
#     975 except JSONDecodeError as e:
#     976     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     977     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
# --> 978     raise RequestsJSONDecodeError(e.msg, e.doc, e.pos)
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
"""
# Definimos el encabezado de autenticación
headers = {
    "Authorization": f"Bearer {my_ath_key}",
    "Accept": "application/json",
    "Content-Type": "application/json" # Especificamos que queremos los datos en formato JSON
}

# Realizamos una solicitud GET para obtener los acordes
chords_response = requests.get(chords_url, headers=headers)

# Verificamos si la solicitud fue exitosa
if chords_response.status_code == 200:
    chords_data = chords_response.json()
    print("Acordes y probabilidades de progresión:", chords_data)
else:
    print("Error al obtener los acordes:", chords_response.status_code, chords_response.text)
"""
